# %% [markdown]
# ## Cultural References in Movies

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import spacy

# %%
data_folder = './Data/MovieSummaries/'
movies = pd.read_csv(data_folder+'movie.metadata.tsv', sep='\t', header=None,  names = ['Wiki ID','movie ID','name', 'release date', 'BOR', 'runtime','languages','countries','genres'])
char= pd.read_csv(data_folder+'character.metadata.tsv', sep='\t', header=None,  names = ['Wiki ID','movie ID', 'release date', 'char name','DOB', 'gender','heght','ethnicity','actor name', 'actor age', 'map ID', 'char ID', 'actor ID' ])

names_char = pd.read_csv(data_folder+'name.clusters.txt', sep='\t', header=None, names=['Name', 'char ID'] )

# %%
# Define the valid date range
start_date = '1678-01-01'
end_date = '2262-04-11'

# Filter out-of-range dates
movies = movies[(movies['release date'] >= start_date) & (movies['release date'] <= end_date)]
#movies['release date'] = pd.to_datetime(movies['release date' ]).dt.strftime('%Y-%m-%d')
print("The oldest movie is from:",movies['release date'].min())
print("The most recent movie is from:",movies['release date'].max())
# Out:
# The oldest movie is from: 1888
# The most recent movie is from: 2016-06-08

# %% [markdown]
# ## Movie summaries

# %%
summaries_path = data_folder+'plot_summaries.txt' 
movie_summaries = pd.DataFrame(columns=['Wiki ID', 'Summary'])

with open(summaries_path, 'r', encoding='utf-8') as file:
    for line in file:
        parts = line.strip().split('\t')
        row=pd.DataFrame([{'Wiki ID': parts[0], 'Summary': parts[1]}])
        movie_summaries = pd.concat([movie_summaries,row],axis=0, ignore_index=True)

# %%
import nltk

from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree

text = '''
Vasha Busa, a Wild Boy
'''


char_clean=char.dropna(subset=['char name'])
for i in range(char_clean.shape[0]):
    text= str(char_clean.iloc[i]['char name'])
    n_words=len(text.split())
    if n_words>=2:
        #print("character name:", text)
        nltk_results = ne_chunk(pos_tag(word_tokenize(text)))
        for nltk_result in nltk_results:
            if type(nltk_result) == Tree:
                name = ''
                for nltk_result_leaf in nltk_result.leaves():
                    name += nltk_result_leaf[0] + ' '
                #print ('Type: ', nltk_result.label(), 'Name: ', name)
                #print ('Name: ', name)

# %% [markdown]
# ## Clean

# %%
import nltk

from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree

# %%
movie_summaries=movie_summaries.dropna()
char=char.dropna(subset=['Wiki ID', 'char name'])

# %%
char.head()
# Out:
#    Wiki ID   movie ID release date                   char name         DOB  \
# 0   975900  /m/03vyhn   2001-08-24                    Akooshay  1958-08-26
# 1   975900  /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
# 2   975900  /m/03vyhn   2001-08-24         Desolation Williams  1969-06-15
# 3   975900  /m/03vyhn   2001-08-24          Sgt Jericho Butler  1967-09-12
# 4   975900  /m/03vyhn   2001-08-24             Bashira Kincaid  1977-09-25
#
#   gender  heght   ethnicity          actor name  actor age      map ID  \
# 0      F  1.620         NaN      Wanda De Jesus       42.0  /m/0bgchxw
# 1      F  1.780  /m/044038p  Natasha Henstridge       27.0   /m/0jys3m
# 2      M  1.727     /m/0x67            Ice Cube       32.0   /m/0jys3g
# 3      M  1.750         NaN       Jason Statham       33.0  /m/02vchl6
# 4      F  1.650         NaN         Clea DuVall       23.0  /m/02vbb3r
#
#       char ID    actor ID
# 0  /m/0bgcj3x  /m/03wcfv7
# 1  /m/0bgchn4   /m/0346l4
# 2  /m/0bgchn_  /m/01vw26l
# 3  /m/0bgchnq   /m/034hyc
# 4  /m/0bgchp9   /m/01y9xg

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Detect names in plot summary, count the number of mentions and link to actor playing the role

# %%
name=''
for i in range(0,1):
    print("hello")
    plot=str(movie_summaries[movie_summaries['Wiki ID']==str(movies.loc[i]['Wiki ID'])]['Summary'])
    #characters=char[char['Wiki ID']==movies.loc[i]['Wiki ID']]
    char_names=char[char['Wiki ID']==movies.loc[i]['Wiki ID']]['char name']
    n_words=len(plot.split())
    names=[]
    name_groups = {}
    if n_words>=2:
        print("Summary of film {0}:".format(i), plot)
        nltk_results = ne_chunk(pos_tag(word_tokenize(plot)))
        for nltk_result in nltk_results:
            if type(nltk_result) == Tree:
                name = ''
                for nltk_result_leaf in nltk_result.leaves():
                    name += nltk_result_leaf[0] + ' '
                names.append(name)

 
    for name in names:
        match_found = False
        name_parts = name.strip().lower().split()
        if len(name_parts) == 2:
            #If full name
            first_name, last_name = name_parts
        elif len(name_parts) == 1:
            #If single name
            first_name, last_name= name_parts[0],""
        else:
            break

        full_name = (first_name, last_name)


        # If name mentionned multiple times, group the mentions
        for group, members in name_groups.items():
            if len(name_parts) == 1:
                if first_name in group[0] or first_name in group[1]:
                    members.append(name)
                    match_found = True
            elif first_name in group[0] or last_name in group[1] or first_name in group[1] or last_name in group[0]:
                members.append(name)
                match_found = True
                break

        if not match_found:
            name_groups[full_name] = [name]


    #Count the number of mentions for each name
    for group, members in name_groups.items():
        print(f"Group: {group}, Members: {members}")
    #     print(len(members))
    
    
    # Match names detected to character of char dataset
    for name in char_names:
        mention=False
        #print(name)
        char_name_parts = name.strip().lower().split()
        #look if each word is in each group
        # for group or for word first?
        for group, members in name_groups.items():
            for word in char_name_parts:
                if word in group:
                    print("Name", name, "has", len(members), "mentions")
                    mention=True
                    #print(char)
                    break
        if mention==False:
            print("Name", name, "has", 0, "mentions")
# Out:
# hello
# Summary of film 0: 22382    Set in the second half of the 22nd century, the film depicts Mars as a planet that has been 84% terraformed, allowing humans to walk on the surface without wearing pressure suits. The Martian society has become largely matriarchal, with women in most positions of authority. The story concerns a police officer, Melanie Ballard , second in command of a small team alongside Sergeant Jericho  sent to pick up and transport a prisoner named Desolation Williams . Arriving at the remote mining town where Williams is being held, Ballard finds virtually all of the people missing. She learns that the miners had discovered an underground doorway created by an ancient Martian civilization. When the door was opened it released "ghosts," disembodied spirits which possessed the miners. Violence ensues, as the possessed miners commit horrific acts of death and destruction, as well as self-mutilation. With their team leader Helena Bradock  murdered, Ballard must fight off the attacking miners, escape the town, and destroy the ghosts, if possible. Unfortunately, her intentions are complicated by the fact that killing a possessed human merely releases the Martian spirit to possess another human. The team eventually decides to blow up a nuclear reactor to try and vaporize all of the ghosts. At several points in the film Sergeant Jericho shows a romantic interest in Ballard, mostly unreciprocated. Ballard's crew along with survivors who manage to gather in the jail are eventually wiped out by the miners after many fierce battles and events , leaving only her and Williams after Sergeant Jericho and the other remaining officers and the two operators of the train are killed upon returning from a brief retreat to finish the fight. Not wanting the authorities to blame the massacre on him, he handcuffs Ballard to her cot and escapes from the train, leaving her to return home and deliver her report, which is received with skepticism by her superiors. While Ballard recuperates at a hospital, the released spirits, who weren't destroyed after all, attack the city. The end scene sets the movie up for a sequel as Williams returns to team up with Ballard to fight the possessed.
# Name: Summary, dtype: object
# Group: ('mars', ''), Members: ['Mars ']
# Group: ('martian', ''), Members: ['Martian ', 'Martian ', 'Martian ']
# Group: ('melanie', 'ballard'), Members: ['Melanie Ballard ', 'Ballard ', 'Ballard ', 'Ballard ', 'Ballard ', 'Ballard ', 'Ballard ', 'Ballard ']
# Group: ('sergeant', 'jericho'), Members: ['Sergeant Jericho ', 'Sergeant Jericho ', 'Sergeant Jericho ']
# Group: ('desolation', 'williams'), Members: ['Desolation Williams ', 'Williams ', 'Williams ', 'Williams ']
# Group: ('helena', 'bradock'), Members: ['Helena Bradock ']
# Name Akooshay has 0 mentions
# Name Lieutenant Melanie Ballard has 8 mentions
# Name Desolation Williams has 4 mentions
# Name Sgt Jericho Butler has 3 mentions
# Name Bashira Kincaid has 0 mentions
# Name Commander Helena Braddock has 1 mentions
# Name Whitlock has 0 mentions
# Name Big Daddy Mars has 1 mentions
# Name Michael Descanso has 0 mentions
# Name Uno has 0 mentions
# Name Dos has 0 mentions
# Name Tres has 0 mentions
# Name McSimms has 0 mentions
# Name Zimmerman has 0 mentions
# Name Benchley has 0 mentions
# Name Rodale has 0 mentions

# %%
char['role']=0

# %%
movies.head()
# Out:
#     Wiki ID    movie ID                                               name  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
#
#   release date         BOR  runtime                           languages  \
# 0   2001-08-24  14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1   2000-02-16         NaN     95.0  {"/m/02h40lc": "English Language"}
# 2         1988         NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3         1987         NaN    110.0  {"/m/02h40lc": "English Language"}
# 4         1983         NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
movie_summaries[movie_summaries['Wiki ID']=='261236'].head()
print(movie_summaries.shape[0])
print(movies.shape[0])
# Out:
# 42306
# 81741

# %%
print(movies.dtypes)
print(movie_summaries.dtypes)
# Out:
# Wiki ID           int64
# movie ID         object
# name             object
# release date     object
# BOR             float64
# runtime         float64
# languages        object
# countries        object
# genres           object
# dtype: object
# Wiki ID    object
# Summary    object
# dtype: object

# %%
common_ids = movies['Wiki ID'].isin(movie_summaries['Wiki ID'])

filtered_movies = movies[common_ids]

print(filtered_movies.index)
# Out:
# Index([    0,     3,     4,     6,    12,    13,    14,    15,    17,    18,
#        ...
#        81725, 81726, 81728, 81729, 81732, 81733, 81736, 81737, 81739, 81740],
#       dtype='int64', length=42207)

# %%
for i in filtered_movies.index:
    print("New summary")
    plot=movie_summaries[movie_summaries['Wiki ID']==filtered_movies.loc[i]['Wiki ID']]['Summary']
    #plot=str(movie_summaries.loc[i]['Summary'])
    print(plot)
# Out:
# New summary
# 22382    Set in the second half of the 22nd century, th...
# Name: Summary, dtype: object
# New summary
# 11300    A series of murders of rich young women throug...
# Name: Summary, dtype: object
# New summary
# 6437    Eva, an upper class housewife, becomes frustra...
# Name: Summary, dtype: object
# New summary
# 34184    Every hundred years, the evil Morgana  returns...
# Name: Summary, dtype: object
# New summary
# 28213    Adam, a San Francisco-based artist who works a...
# Name: Summary, dtype: object
# New summary
# 12253    {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...
# Name: Summary, dtype: object
# New summary
# 9200    Serap, a young actress with a strong, lively p...
# Name: Summary, dtype: object
# New summary
# 228     The story starts as one of the robots flies i...
# Name: Summary, dtype: object
# New summary
# 16384    The film opens with Mary Poppins  perched in a...
# Name: Summary, dtype: object
# New summary
# 7170    Otto Brosowski, a communist miner, writes to t...
# Name: Summary, dtype: object
# New summary
# 39800    Jimmy ([[Hiroshi Watanabe  loves dinosaurs and...
# Name: Summary, dtype: object
# New summary
# 40061    The film opens with a simpleton from a small v...
# Name: Summary, dtype: object
# New summary
# 20986    A young 20-year-old named Jody  lives with his...
# Name: Summary, dtype: object
# New summary
# 17788    Shalini 'Shalu' lives a wealthy lifestyle with...
# Name: Summary, dtype: object
# New summary
# 23538    Professor Kurian Fernandez , a convict escapes...
# Name: Summary, dtype: object
# New summary
# 35593    Mary, an orphan lives in an orphanage run by n...
# Name: Summary, dtype: object
# New summary
# 22608    Anoop Chandran , is a famous writer and award ...
# Name: Summary, dtype: object
# New summary
# 18377    Perry is an English chemist working for a pain...
# Name: Summary, dtype: object
# New summary
# 18707    The film is the story of Yamuna  whose life is...
# Name: Summary, dtype: object
# New summary
# 26700    Archie Andrews, fifteen years after graduating...
# Name: Summary, dtype: object
# New summary
# 11108    An example of the film's comedic tone comes in...
# Name: Summary, dtype: object
# New summary
# 40243    Ruby and Claude Montgomery are a very insecure...
# Name: Summary, dtype: object
# New summary
# 34015    The film is a collision of three separate stor...
# Name: Summary, dtype: object
# New summary
# 36627    In the fictional farming village of Tlachtlán,...
# Name: Summary, dtype: object
# New summary
# 31309    A Japanese businessman sees a woman being grop...
# Name: Summary, dtype: object
# New summary
# 31580    The Great New Wonderful is a series of vignett...
# Name: Summary, dtype: object
# New summary
# 38316    Randy Bodek  is a rebellious college slacker, ...
# Name: Summary, dtype: object
# New summary
# 8250    Chandra Mukhi , a princess of a heavenly kingd...
# Name: Summary, dtype: object
# New summary
# 2511    The film focuses on the conflict between Maxim...
# Name: Summary, dtype: object
# New summary
# 5222    In the 1980s, video games were synonymous with...
# Name: Summary, dtype: object
# New summary
# 7974    The film centers on Mike Halligan, a retired c...
# Name: Summary, dtype: object
# New summary
# 40069    After coming off a successful comedy tour, Dol...
# Name: Summary, dtype: object
# New summary
# 40246    Dr. Emil Hobbes  is conducting unorthodox expe...
# Name: Summary, dtype: object
# New summary
# 30226    After running away from a shoot out, the outla...
# Name: Summary, dtype: object
# New summary
# 31167    Raghu Shukla lives with his wife Sarojini, son...
# Name: Summary, dtype: object
# New summary
# 19103    The film tells the story of six mental cases, ...
# Name: Summary, dtype: object
# New summary
# 19772    Told through archival photos and footage, spac...
# Name: Summary, dtype: object
# New summary
# 33530    Sir Philip Ashlow , his neglected wife, Lady A...
# Name: Summary, dtype: object
# New summary
# 39443    The film portrays an aggressive and belligeren...
# Name: Summary, dtype: object
# New summary
# 5509    The film is about the harsh period of Reconstr...
# Name: Summary, dtype: object
# New summary
# 11144    Best friends Clay Clayburn and Will Denning gr...
# Name: Summary, dtype: object
# New summary
# 38841    In the heart of the Canadian wilderness, sultr...
# Name: Summary, dtype: object
# New summary
# 468    The film opens in 1991, with the funeral of a ...
# Name: Summary, dtype: object
# New summary
# 7996    The first part of the film shows the police in...
# Name: Summary, dtype: object
# New summary
# 5148    Aboard the cargo ship McRuby, docked in New Yo...
# Name: Summary, dtype: object
# New summary
# 40587    Arun Sharma  is a spy working for RAW . He set...
# Name: Summary, dtype: object
# New summary
# 20047    One evening while eagerly awaiting a date with...
# Name: Summary, dtype: object
# New summary
# 26847    The Polish artist Julia and her husband Piotr,...
# Name: Summary, dtype: object
# New summary
# 26944    In 1976, during the political turmoil in Argen...
# Name: Summary, dtype: object
# New summary
# 4042    The story tells of a young, pregnant woman ([[...
# Name: Summary, dtype: object
# New summary
# 24786    In 1918, against the background of political e...
# Name: Summary, dtype: object
# New summary
# 33360    The film starts off with two girls talking to ...
# Name: Summary, dtype: object
# New summary
# 24491    Kedarnath Bhargav, his wife, Laxmi, and two so...
# Name: Summary, dtype: object
# New summary
# 42256    Dr. David Lowell's  research is carried out in...
# Name: Summary, dtype: object
# New summary
# 14522    An old friend of the boys returns to town and ...
# Name: Summary, dtype: object
# New summary
# 28202    ChromeSkull: Laid to Rest 2 picks up three mon...
# Name: Summary, dtype: object
# New summary
# 7945    Steve Randall  is an independent trucker who i...
# Name: Summary, dtype: object
# New summary
# 4845    The film follows Jack Hopkins , an aircraft de...
# Name: Summary, dtype: object
# New summary
# 16634    An officer in the violent crimes division, Dae...
# Name: Summary, dtype: object
# New summary
# 13964    A new bullet train is speeding passengers to L...
# Name: Summary, dtype: object
# New summary
# 39323    Arthur Kirkland  is a hotheaded but idealistic...
# Name: Summary, dtype: object
# New summary
# 5290    Children of Glory commemorates Hungary's Revol...
# Name: Summary, dtype: object
# New summary
# 3687    Ahn Mo-rae and Han Sang-in have been friends s...
# Name: Summary, dtype: object
# New summary
# 21006    The film opens in 1940, with Lawrence in a scr...
# Name: Summary, dtype: object
# New summary
# 32195    The film is a hybrid between narrative structu...
# Name: Summary, dtype: object
# New summary
# 19555    {{Expand section}} In late October 1943, a bat...
# Name: Summary, dtype: object
# New summary
# 28621    Twin zoologists Oswald and Oliver Deuce  are a...
# Name: Summary, dtype: object
# New summary
# 21670    {{Plot}} Jerry is mixing a potion. When he dri...
# Name: Summary, dtype: object
# New summary
# 651    Pedarayudu  is a very kind-hearted, discipline...
# Name: Summary, dtype: object
# New summary
# 40168    Jimmy "The Saint" Tosnia  is a dapper ex-gangs...
# Name: Summary, dtype: object
# New summary
# 9329    Priya Amal Raj  loses her mother at a very you...
# Name: Summary, dtype: object
# New summary
# 27744    {{Plot}} Truck driver Martin "Rubber Duck" Pen...
# Name: Summary, dtype: object
# New summary
# 22327    Sea Org officer Ronnie Miscavige describes the...
# Name: Summary, dtype: object
# New summary
# 17161    The episode starts at the Krusty Krab, when Sp...
# Name: Summary, dtype: object
# New summary
# 28090    14-year-old Danny O'Neil  is madly in love wit...
# Name: Summary, dtype: object
# New summary
# 2260    Betty offers to take her nephew Little Jimmy t...
# Name: Summary, dtype: object
# New summary
# 28269    The film opens with a woman walking her dog do...
# Name: Summary, dtype: object
# New summary
# 36220    The film begins with a voice over explaining t...
# Name: Summary, dtype: object
# New summary
# 23631     Miss Dove, commonly referred to as "the terri...
# Name: Summary, dtype: object
# New summary
# 36174    Three women ridiculed by their spouses glide t...
# Name: Summary, dtype: object
# New summary
# 14082    Matko Destanov, a small-time Roma smuggler and...
# Name: Summary, dtype: object
# New summary
# 29190    Carrie Snyder  is a prostitute, who is forced ...
# Name: Summary, dtype: object
# New summary
# 29584    Charles Farmer is a former astronaut-in-traini...
# Name: Summary, dtype: object
# New summary
# 33037    David Sumner , a timid American mathematician,...
# Name: Summary, dtype: object
# New summary
# 22780    Oru Black & White Kudumbam movie is about a ha...
# Name: Summary, dtype: object
# New summary
# 19523    {{Expand section}} A reformed jewel thief trie...
# Name: Summary, dtype: object
# New summary
# 6234    Sometime after the events in Critters 2, Charl...
# Name: Summary, dtype: object
# New summary
# 40582    In the not-too-distant future, androids have c...
# Name: Summary, dtype: object
# New summary
# 32949    The story is about an ostracized teenager, Cli...
# Name: Summary, dtype: object
# New summary
# 8219    Kibera Kid is the story of Otieno, a 12 year o...
# Name: Summary, dtype: object
# New summary
# 7138    Vishnu  is the regional manager in a travels c...
# Name: Summary, dtype: object
# New summary
# 17428    Again and again, people disappear from a diamo...
# Name: Summary, dtype: object
# New summary
# 36813    Hairy and rowdy creatures called rolleys sail ...
# Name: Summary, dtype: object
# New summary
# 41790    At night the tenants of a housing project lock...
# Name: Summary, dtype: object
# New summary
# 42158    The film is divided into five segments , each ...
# Name: Summary, dtype: object
# New summary
# 41072    Bharat Nagar is a city in modern secular India...
# Name: Summary, dtype: object
# New summary
# 12818    The Catastrophe is a surreal drama/mystery sho...
# Name: Summary, dtype: object
# New summary
# 38431     In the summer of 1959, local boy Danny Zuko a...
# Name: Summary, dtype: object
# New summary
# 5759    Paul  is a projectionist in a Detroit theater ...
# Name: Summary, dtype: object
# New summary
# 14056    A rich novelist, Stephen Byrne, who lives and ...
# Name: Summary, dtype: object
# New summary
# 6355    Frederick Ward is a cattle drover earning mone...
# Name: Summary, dtype: object
# New summary
# 27851    Pierre Martel , a young Parisian businessman, ...
# Name: Summary, dtype: object
# New summary
# 30576    One night in winter, a young girl named Gerda ...
# Name: Summary, dtype: object
# New summary
# 32596    María Teresa  is a wealthy young woman who fin...
# Name: Summary, dtype: object
# New summary
# 7186    The film is a slice of a housewife's life in 1...
# Name: Summary, dtype: object
# New summary
# 18638    The movie is set in Korea's Joseon Dynasty, du...
# Name: Summary, dtype: object
# New summary
# 26003    A woman and man who met at a wedding reception...
# Name: Summary, dtype: object
# New summary
# 27660    Jane Austen  is the younger daughter of Revere...
# Name: Summary, dtype: object
# New summary
# 30740    Max decides to commit suicide and forces Bud t...
# Name: Summary, dtype: object
# New summary
# 32804    The film revolves around the attempts of write...
# Name: Summary, dtype: object
# New summary
# 22097    The film deals with a woman's  fight against c...
# Name: Summary, dtype: object
# New summary
# 167    Computer experts around the world strive towar...
# Name: Summary, dtype: object
# New summary
# 5803    On October 6, 1970, while on holiday in Istanb...
# Name: Summary, dtype: object
# New summary
# 18930    It’s midnight, and Jeanne  is awakened by wail...
# Name: Summary, dtype: object
# New summary
# 10717    Omni Consumer Products , on the verge of bankr...
# Name: Summary, dtype: object
# New summary
# 2073    A redneck officer  is put in charge of a squad...
# Name: Summary, dtype: object
# New summary
# 20371    Junie , is an ice cream vendor, who goes aroun...
# Name: Summary, dtype: object
# New summary
# 37303    Ajith Kumar , who lives with his grandmother i...
# Name: Summary, dtype: object
# New summary
# 10047    An American Intelligence Agent and Nazi hunter...
# Name: Summary, dtype: object
# New summary
# 144    Contemporary New Orleans jazz musicians discus...
# Name: Summary, dtype: object
# New summary
# 36128    Martha Heyer, a virginal 31 years old libraria...
# Name: Summary, dtype: object
# New summary
# 28800    In 1941 Lt. Commander Jeffords, an American se...
# Name: Summary, dtype: object
# New summary
# 2705    In this film, which is based loosely on the an...
# Name: Summary, dtype: object
# New summary
# 41333    The story has three themes which run concurren...
# Name: Summary, dtype: object
# New summary
# 28678    Six introverted individuals, bored with their ...
# Name: Summary, dtype: object
# New summary
# 14546    Kenan is a 35-year-old toll booth attendant st...
# Name: Summary, dtype: object
# New summary
# 17738    On the planet Krypton, using evidence provided...
# Name: Summary, dtype: object
# New summary
# 7631    Twist's mother dies in childbirth in the middl...
# Name: Summary, dtype: object
# New summary
# 33159    The film follows the friends Leo and Lenny, wh...
# Name: Summary, dtype: object
# New summary
# 37631    In the post Spanish Civil War years, Catalan k...
# Name: Summary, dtype: object
# New summary
# 26970    Rock star Roddy Usher (played by [[James Johns...
# Name: Summary, dtype: object
# New summary
# 3732    A group of English schoolchildren, living in t...
# Name: Summary, dtype: object
# New summary
# 11146    A father and son go hunting in the mountains. ...
# Name: Summary, dtype: object
# New summary
# 27872    Keith Lussier - a hard working man - and his w...
# Name: Summary, dtype: object
# New summary
# 8429    An elderly woman, Elmira Johnson, uses a Ouija...
# Name: Summary, dtype: object
# New summary
# 21518    The USS Charleston  in On the Beach is a 688i ...
# Name: Summary, dtype: object
# New summary
# 7970    Charlie Tuttle  is a partner in a successful l...
# Name: Summary, dtype: object
# New summary
# 20374    The Afghan kingdom of Baharistan is ruled by a...
# Name: Summary, dtype: object
# New summary
# 33503    The film takes place in Marseille, France, and...
# Name: Summary, dtype: object
# New summary
# 1081    Vera  is a femme fatale for the 21st century: ...
# Name: Summary, dtype: object
# New summary
# 15814    The film is centered on two men in a bathtub; ...
# Name: Summary, dtype: object
# New summary
# 528    The Texas State University Fightin' Armadillos...
# Name: Summary, dtype: object
# New summary
# 33501    Jeff Harper sails to the tropical paradise Ahm...
# Name: Summary, dtype: object
# New summary
# 41399    Summer Pozzi , a Chicago-based flight attendan...
# Name: Summary, dtype: object
# New summary
# 6127    In the 19th century, Benjamin Barker , a skill...
# Name: Summary, dtype: object
# New summary
# 24825    Siddhant Rai is a wealthy widower who lives wi...
# Name: Summary, dtype: object
# New summary
# 37839    The Stooges are choreographers at B. O. Pictur...
# Name: Summary, dtype: object
# New summary
# 10503    A defecting Russian diplomat has arranged to m...
# Name: Summary, dtype: object
# New summary
# 27005    The film is structured around lengthy flashbac...
# Name: Summary, dtype: object
# New summary
# 3553    Advertising executive Nick Beam  thinks his li...
# Name: Summary, dtype: object
# New summary
# 32009    Set in today’s Mumbai, Barah Aana revolves aro...
# Name: Summary, dtype: object
# New summary
# 30952    U.S. Air Force test pilot Major Bill Allison  ...
# Name: Summary, dtype: object
# New summary
# 2465    The mining town of Cedar City, Utah, is ruled ...
# Name: Summary, dtype: object
# New summary
# 18529    One day after the events of Friday the 13th Pa...
# Name: Summary, dtype: object
# New summary
# 14914    {{Expand section}} A man whose wife has desert...
# Name: Summary, dtype: object
# New summary
# 39430    Rahul ([[Dev  & Ria  met as they are independe...
# Name: Summary, dtype: object
# New summary
# 10252      April 1945. The Nazi army is losing the war ...
# Name: Summary, dtype: object
# New summary
# 10605    A melodrama of a wealthy Los Angeles family - ...
# Name: Summary, dtype: object
# New summary
# 3131    Dar, the Beastmaster , is back and now he has ...
# Name: Summary, dtype: object
# New summary
# 40675    Amy Medford  is a dutiful housewife of the ear...
# Name: Summary, dtype: object
# New summary
# 34348    Weather presenter Jin-su is involved in a car ...
# Name: Summary, dtype: object
# New summary
# 24623    Murari has dream of becoming an actor, but his...
# Name: Summary, dtype: object
# New summary
# 3680    Newlywed Carl  goes to war where he endures ma...
# Name: Summary, dtype: object
# New summary
# 5101    Four homeless art students move into an abando...
# Name: Summary, dtype: object
# New summary
# 19215    After the mayor of the fictional village San P...
# Name: Summary, dtype: object
# New summary
# 35827    In Spring 1989, Alex  and Annie Morrell  finis...
# Name: Summary, dtype: object
# New summary
# 35195    On the lookout for employment, Ashok  sees the...
# Name: Summary, dtype: object
# New summary
# 14298    It is 1982 and Lizzie Borden High School is ho...
# Name: Summary, dtype: object
# New summary
# 33276    The film takes place in Paris, 1793: durung th...
# Name: Summary, dtype: object
# New summary
# 30367    634 A.D.:Though General Amdar is able to win t...
# Name: Summary, dtype: object
# New summary
# 6615    The film is set in 1918. Riyo  is a "city girl...
# Name: Summary, dtype: object
# New summary
# 39239    A motorbiker , who early in the film was unabl...
# Name: Summary, dtype: object
# New summary
# 34002    When freeloader Phil is tossed out by the love...
# Name: Summary, dtype: object
# New summary
# 35868    The Winter Wishes Festival is finally coming a...
# Name: Summary, dtype: object
# New summary
# 14115    In the 1840s, two sisters fall in love with th...
# Name: Summary, dtype: object
# New summary
# 11410    When stroke victim Violet Kellty dies in her h...
# Name: Summary, dtype: object
# New summary
# 26546    Betty holds a "Betty Boop Exposition", where s...
# Name: Summary, dtype: object
# New summary
# 39945    Bheemasena Rao  is a dignified and respectful ...
# Name: Summary, dtype: object
# New summary
# 8351     Dr. Barnaby Fulton , a research chemist worki...
# Name: Summary, dtype: object
# New summary
# 22180    It's summer, and 18-year-old Sean Roberts  has...
# Name: Summary, dtype: object
# New summary
# 24667    A mental patient who believes himself to be Je...
# Name: Summary, dtype: object
# New summary
# 11540    A passion for golf drives this story about fam...
# Name: Summary, dtype: object
# New summary
# 25159    Thamizh Selvan ([[Prabhu , an orphan who works...
# Name: Summary, dtype: object
# New summary
# 30424    Socialite Claire Gregory  attends a party and ...
# Name: Summary, dtype: object
# New summary
# 14122    A group of teenage girls spends the night in a...
# Name: Summary, dtype: object
# New summary
# 30846    {{Expand section}} Rosie , a scriptwriter for ...
# Name: Summary, dtype: object
# New summary
# 42214    This is the story of two lads from Belfast as ...
# Name: Summary, dtype: object
# New summary
# 22606    Tefeeda is a girl who leaves her brother-in-la...
# Name: Summary, dtype: object
# New summary
# 6789    Against the backdrop of the Bourbon Restoratio...
# Name: Summary, dtype: object
# New summary
# 17238    Two high school seniors from different social ...
# Name: Summary, dtype: object
# New summary
# 30369    On September 27, 1941, Reinhard Heydrich, one ...
# Name: Summary, dtype: object
# New summary
# 8379    The film takes place in Koishikawa, a district...
# Name: Summary, dtype: object
# New summary
# 24097    Story of a boy named Ibu during Liberation war...
# Name: Summary, dtype: object
# New summary
# 4416    In 1813, the war turns in favour of the Britis...
# Name: Summary, dtype: object
# New summary
# 28263    Lovelorn Kim Hyeon-gon , who has fallen for co...
# Name: Summary, dtype: object
# New summary
# 3420    Andrzej  and Krystyna  are driving to a lake t...
# Name: Summary, dtype: object
# New summary
# 30810    While traipsing through the Ookaboochie Swamps...
# Name: Summary, dtype: object
# New summary
# 24685    Marcela is an immigrant woman with money diffi...
# Name: Summary, dtype: object
# New summary
# 37926    The film begins with Michael McCrea , a perpet...
# Name: Summary, dtype: object
# New summary
# 10006    The educational film aims to help the "people ...
# Name: Summary, dtype: object
# New summary
# 31292    Mamarazzi is the story of a mother who constan...
# Name: Summary, dtype: object
# New summary
# 26832    In this musical comedy, a Cockney flower girl ...
# Name: Summary, dtype: object
# New summary
# 12156    Mildred decides that she and George will celeb...
# Name: Summary, dtype: object
# New summary
# 23188    Achuthan Nair , an honest and sincere police c...
# Name: Summary, dtype: object
# New summary
# 24270    During the Great Depression, a man  is thrown ...
# Name: Summary, dtype: object
# New summary
# 24342     Sarah Michelle Gellar stars as Brett Eisenber...
# Name: Summary, dtype: object
# New summary
# 31318    Rahul Tiwari  is in love with Sandhya Patil  &...
# Name: Summary, dtype: object
# New summary
# 29906    Belu  and Bhola  are left to the care of their...
# Name: Summary, dtype: object
# New summary
# 28126    Yamraaj is the story of two thieves Birju  and...
# Name: Summary, dtype: object
# New summary
# 5012    Kadosh is a bleak drama about the plight of wo...
# Name: Summary, dtype: object
# New summary
# 26984    Calvert College begins taking football more se...
# Name: Summary, dtype: object
# New summary
# 17191    Separated by both physical and emotional dista...
# Name: Summary, dtype: object
# New summary
# 38650    The main characters are Heinz Bösel  and Kurt ...
# Name: Summary, dtype: object
# New summary
# 26775    JB  is a wealthy industrialist who decides to ...
# Name: Summary, dtype: object
# New summary
# 17310    9-year-old Elias and his father are going for ...
# Name: Summary, dtype: object
# New summary
# 8912    Edna Buxton  is a steel heiress from Chestnut ...
# Name: Summary, dtype: object
# New summary
# 36028    Wealthy housewife and children's author Cathry...
# Name: Summary, dtype: object
# New summary
# 24544    The opening shot is of a shoe lying in the gut...
# Name: Summary, dtype: object
# New summary
# 681    Wealthy French playboy Toto Duryea ([[Frank Fa...
# Name: Summary, dtype: object
# New summary
# 2040    The series opens with Jerry Seinfeld and Georg...
# Name: Summary, dtype: object
# New summary
# 15856    The year is 1910. In the rural German village ...
# Name: Summary, dtype: object
# New summary
# 18920    Jean Brodie is a teacher at the Marcia Blaine ...
# Name: Summary, dtype: object
# New summary
# 20815    A young Lakota Sioux  is adopted by a wealthy ...
# Name: Summary, dtype: object
# New summary
# 16680    While visiting Grace Allingham in wartime Lond...
# Name: Summary, dtype: object
# New summary
# 3789    After escaping death, former FBI agent Adam Ri...
# Name: Summary, dtype: object
# New summary
# 28134    Garage Days is the story of a young Sydney gar...
# Name: Summary, dtype: object
# New summary
# 37458    Tito , a traveling circus clown, finds an aban...
# Name: Summary, dtype: object
# New summary
# 24346    The story begins with Samantha  breaking up wi...
# Name: Summary, dtype: object
# New summary
# 31759    Inspector Clouseau  is called to the country h...
# Name: Summary, dtype: object
# New summary
# 35529    Anjali  is a beautiful and idealistic girl fro...
# Name: Summary, dtype: object
# New summary
# 39928    Bugs Bunny boards the Chattanooga Choo Choo an...
# Name: Summary, dtype: object
# New summary
# 11400    Gabe Ryan  is released from reform school and ...
# Name: Summary, dtype: object
# New summary
# 3644    It is believed that 'Media' is the fourth pill...
# Name: Summary, dtype: object
# New summary
# 33490    {{Plot}} Shaft, a private detective, emerges f...
# Name: Summary, dtype: object
# New summary
# 40516     Most of the plot is unknown; The Ghost of Slu...
# Name: Summary, dtype: object
# New summary
# 32947    Leslie Wright  is a straight-shooting physical...
# Name: Summary, dtype: object
# New summary
# 22495    {{Plot}} At the beginning of the movie Casper ...
# Name: Summary, dtype: object
# New summary
# 20840    In Seoul, 1988, Greg Louganis  hits the diving...
# Name: Summary, dtype: object
# New summary
# 15029    In 1900, lumberman Jim Fallon  greedily eyes t...
# Name: Summary, dtype: object
# New summary
# 36928    The film follows multiple characters' lives an...
# Name: Summary, dtype: object
# New summary
# 33875    This film is a love story of two youngsters wh...
# Name: Summary, dtype: object
# New summary
# 1417    Maggie O'Connor's  life revolves around her jo...
# Name: Summary, dtype: object
# New summary
# 4355    Mengejar Mas-Mas is an Indonesia drama comedy ...
# Name: Summary, dtype: object
# New summary
# 13768    The films opens in present. 75-year-old Mary C...
# Name: Summary, dtype: object
# New summary
# 5597    As the war ended, some soldiers of color refus...
# Name: Summary, dtype: object
# New summary
# 1143    The film centers on Park Ranger Hollister , wh...
# Name: Summary, dtype: object
# New summary
# 14530    The ESU Timberwolves are entering a season wit...
# Name: Summary, dtype: object
# New summary
# 8801    As the film begins, Geraldine ejects Joe from ...
# Name: Summary, dtype: object
# New summary
# 5623    The film opens with a flashback to the Vietnam...
# Name: Summary, dtype: object
# New summary
# 19240    The Pink Panther is hired as a cook at a cafe ...
# Name: Summary, dtype: object
# New summary
# 31565    Sudo  is a disfigured World War II soldier who...
# Name: Summary, dtype: object
# New summary
# 41381    "Blackie" Norton , a saloonkeeper and gambler ...
# Name: Summary, dtype: object
# New summary
# 35358    Set in the early 90s, Dana , a recently divorc...
# Name: Summary, dtype: object
# New summary
# 17168    When occultist uncle Dr. Plato Zorba wills a h...
# Name: Summary, dtype: object
# New summary
# 3051    Set in third century BC China, the story of Th...
# Name: Summary, dtype: object
# New summary
# 8773    Aurore Gagnon, born in 1909 to Marie-Anne Caro...
# Name: Summary, dtype: object
# New summary
# 22800    Francis, a successful writer of crime novels a...
# Name: Summary, dtype: object
# New summary
# 40659    Penny and Mary are sisters living together in ...
# Name: Summary, dtype: object
# New summary
# 9819    The story takes place in 1851 and deals with a...
# Name: Summary, dtype: object
# New summary
# 3124    Imam plays Hasanin, an uneducated man who leav...
# Name: Summary, dtype: object
# New summary
# 40849    At the start of the film, George Burns tells u...
# Name: Summary, dtype: object
# New summary
# 17851    Shankar, a wealthy bachelor falls in love with...
# Name: Summary, dtype: object
# New summary
# 37798    This film takes place during the events of Get...
# Name: Summary, dtype: object
# New summary
# 24797    {{plot}} Ernest  works as a janitor at Chickas...
# Name: Summary, dtype: object
# New summary
# 29094    Journey is the allegorical story of a young wo...
# Name: Summary, dtype: object
# New summary
# 15169    Coach Lambeau Fields  is pathetic. He has the ...
# Name: Summary, dtype: object
# New summary
# 5238    Following a tip from a small time lodge owner ...
# Name: Summary, dtype: object
# New summary
# 2796    Fur trapper Brule Conway sets Rin Tin Tin Jr. ...
# Name: Summary, dtype: object
# New summary
# 21139    "It is not a language that flows out of you", ...
# Name: Summary, dtype: object
# New summary
# 11131    The film deals with student strength. Shiva , ...
# Name: Summary, dtype: object
# New summary
# 25346    Unable and unwilling to live apart from his gi...
# Name: Summary, dtype: object
# New summary
# 15420    1609: Shakespeare is struggling to complete hi...
# Name: Summary, dtype: object
# New summary
# 40856    Ganesh  is from a middle-class family. He make...
# Name: Summary, dtype: object
# New summary
# 2877    In the days leading up to the Russian Revoluti...
# Name: Summary, dtype: object
# New summary
# 5232    The People's Republic of China is severing rel...
# Name: Summary, dtype: object
# New summary
# 37477    In every port, sailor Bill, Spencer Tracy, mee...
# Name: Summary, dtype: object
# New summary
# 258    Ned Kynaston  is one of the leading actors of ...
# Name: Summary, dtype: object
# New summary
# 12472    Shakthivel  is the son of a wealthy industrial...
# Name: Summary, dtype: object
# New summary
# 18497    Set in the period between 1784 and 1789, the f...
# Name: Summary, dtype: object
# New summary
# 4240    Thomas Avery is an American ophthalmologist wh...
# Name: Summary, dtype: object
# New summary
# 11619    The film is based on Raj ([[Govinda  who has a...
# Name: Summary, dtype: object
# New summary
# 34286    The film begins circa 2008  with an elderly La...
# Name: Summary, dtype: object
# New summary
# 21832    A photographer and a group of American models ...
# Name: Summary, dtype: object
# New summary
# 25342    Roy , Amir , Soorya  and Gouri  come from enti...
# Name: Summary, dtype: object
# New summary
# 75    Littlefoot and his friends are constantly bein...
# Name: Summary, dtype: object
# New summary
# 4876    Coming to the assistance of a nanny who is alm...
# Name: Summary, dtype: object
# New summary
# 38000    Cris Johnson  can see into his future. He can ...
# Name: Summary, dtype: object
# New summary
# 29173    Paramvir Singh  is a Non-resident Indian  livi...
# Name: Summary, dtype: object
# New summary
# 18398    Set in the 19th century, the plot centered aro...
# Name: Summary, dtype: object
# New summary
# 18434    In Bandrika, a fictional country in an "uncivi...
# Name: Summary, dtype: object
# New summary
# 26014    Emperor Chandragupta Maurya is taking a sanyas...
# Name: Summary, dtype: object
# New summary
# 28845    Max is a young lesbian student in Chicago who ...
# Name: Summary, dtype: object
# New summary
# 32124    Frank Carden  is a professional assassin who h...
# Name: Summary, dtype: object
# New summary
# 24746    Sasha  is a boy who lives with his mother  and...
# Name: Summary, dtype: object
# New summary
# 23154    Miles Campbell, recent graduate of a Christian...
# Name: Summary, dtype: object
# New summary
# 12490    According to Devil's Playground, at the age of...
# Name: Summary, dtype: object
# New summary
# 13614    Michael Lynch is one of Dublin's most notoriou...
# Name: Summary, dtype: object
# New summary
# 3021    Set in the late 15th century during the reign ...
# Name: Summary, dtype: object
# New summary
# 16880    The plot concerns the adventures of João Grilo...
# Name: Summary, dtype: object
# New summary
# 34488     Elmer approaches one of Bugs' holes, puts dow...
# Name: Summary, dtype: object
# New summary
# 14156    In ancient times, the gods Zeus, Poseidon, and...
# Name: Summary, dtype: object
# New summary
# 41699    The film tells the story of David Vass , an ob...
# Name: Summary, dtype: object
# New summary
# 6596    One morning, hitmen Charlie  and Lee  enter a ...
# Name: Summary, dtype: object
# New summary
# 37605    A Senate Armed Services Committee interviews a...
# Name: Summary, dtype: object
# New summary
# 4863    Alya , a 20-year-old woman becomes engaged to ...
# Name: Summary, dtype: object
# New summary
# 23702    A sequel to the 1977 film Outrageous! Too Outr...
# Name: Summary, dtype: object
# New summary
# 25124    Nagarjuna has played an auto driver role and l...
# Name: Summary, dtype: object
# New summary
# 38339    Shortly after the Columbine High School massac...
# Name: Summary, dtype: object
# New summary
# 18271    Set on the fictional San Piedro Island in the ...
# Name: Summary, dtype: object
# New summary
# 14378    Johnny Bhai  is an amusing older married man w...
# Name: Summary, dtype: object
# New summary
# 3078    Set in the 1910s, the story opens with a Grand...
# Name: Summary, dtype: object
# New summary
# 37474    In the build-up to the Normandy landings, thou...
# Name: Summary, dtype: object
# New summary
# 22721    The film is set in late 1980s Moscow. Standing...
# Name: Summary, dtype: object
# New summary
# 7119    Nine separate stories intertwine into one come...
# Name: Summary, dtype: object
# New summary
# 8342    Mohanachandran Nair ([[Kailash  is a Malayali ...
# Name: Summary, dtype: object
# New summary
# 10169    Wally Sparks  is the host of a sleazy tabloid-...
# Name: Summary, dtype: object
# New summary
# 36292    The film begins with scenes of life in Wyoming...
# Name: Summary, dtype: object
# New summary
# 37591    Marshal Antonio Carotenuto arrives back in his...
# Name: Summary, dtype: object
# New summary
# 17873    The film opens with Harlow as a struggling ext...
# Name: Summary, dtype: object
# New summary
# 14039    After spending time in New York, Billy Hayes r...
# Name: Summary, dtype: object
# New summary
# 13950    The film is based on a true story, Su-hyon  tr...
# Name: Summary, dtype: object
# New summary
# 39081    The plot revolves around the complications bro...
# Name: Summary, dtype: object
# New summary
# 33317    Even though being able to withdraw from the Li...
# Name: Summary, dtype: object
# New summary
# 5221    The wife of a small town doctor tires of his s...
# Name: Summary, dtype: object
# New summary
# 13120    The chairman of a top-flight English football ...
# Name: Summary, dtype: object
# New summary
# 4466    The film opens with Jake Raye as he fights Mic...
# Name: Summary, dtype: object
# New summary
# 40328    Lizabeth Scott plays Elsa Jenner, widowed moth...
# Name: Summary, dtype: object
# New summary
# 14667    Boog plans an annual guys trip to spend time w...
# Name: Summary, dtype: object
# New summary
# 10891    {{plot}} The Virginia Brothers, a team of acro...
# Name: Summary, dtype: object
# New summary
# 17178    Niloofar, a twelve-year-old girl, is dreaming ...
# Name: Summary, dtype: object
# New summary
# 4908    This folktale story is set in a village where ...
# Name: Summary, dtype: object
# New summary
# 1314    Tanya  is a female model who lives with her bo...
# Name: Summary, dtype: object
# New summary
# 13207    The opening sequence is a 1943 black-and-white...
# Name: Summary, dtype: object
# New summary
# 25856    Robin Shea is a mischief-causing temptress, a ...
# Name: Summary, dtype: object
# New summary
# 21022    The story begins with rock star Vince Raven  p...
# Name: Summary, dtype: object
# New summary
# 31266    The voice of Archie Goodwin  introduces us to ...
# Name: Summary, dtype: object
# New summary
# 8446    Jennie Logan and her husband Michael ([[Alan F...
# Name: Summary, dtype: object
# New summary
# 32218    The film is a scathing indictment of Californi...
# Name: Summary, dtype: object
# New summary
# 25128    In Bruxelles, two rival gangs of gangsters con...
# Name: Summary, dtype: object
# New summary
# 3333    Thyagarajan and Kamala aer in love and are sep...
# Name: Summary, dtype: object
# New summary
# 20767    The film is about two brothers who reside in B...
# Name: Summary, dtype: object
# New summary
# 31930    Kalu is a taxi-driver in Mumbai, India. He has...
# Name: Summary, dtype: object
# New summary
# 10114    Chirammal Enashu Francis, a.k.a. Pranchiyettan...
# Name: Summary, dtype: object
# New summary
# 29183    A maniac bomber is ruthlessly targeting Seattl...
# Name: Summary, dtype: object
# New summary
# 117    Vishwanathan , an innocent young man in Kochi ...
# Name: Summary, dtype: object
# New summary
# 18816    In 1943, a WREN  and an RAF pilot  meet at an ...
# Name: Summary, dtype: object
# New summary
# 7274    An elephant punctures a rubber tree, whose spr...
# Name: Summary, dtype: object
# New summary
# 16666    The movie opens with a distressed woman being ...
# Name: Summary, dtype: object
# New summary
# 22963    A German high school student, Sonja  wins an e...
# Name: Summary, dtype: object
# New summary
# 15345    In June 2008, the Benson family moves into 112...
# Name: Summary, dtype: object
# New summary
# 28698    Ju is a nine-year-old boy growing up in the af...
# Name: Summary, dtype: object
# New summary
# 4162    Taking place over the course of a single day, ...
# Name: Summary, dtype: object
# New summary
# 40145    The film is the story of Manu pursued by band ...
# Name: Summary, dtype: object
# New summary
# 8636    Recovered: Journeys Through the Autism Spectru...
# Name: Summary, dtype: object
# New summary
# 24946    Sam  and Cheska  are on their way to fulfillin...
# Name: Summary, dtype: object
# New summary
# 9287    Scandals and pratfalls abound in this satirica...
# Name: Summary, dtype: object
# New summary
# 17591    Colin Glasgow returning home after the murder ...
# Name: Summary, dtype: object
# New summary
# 12797    In 1933, Freya Roth  is a young German girl en...
# Name: Summary, dtype: object
# New summary
# 21829    Over the course of their marriage, Geoffrey Ly...
# Name: Summary, dtype: object
# New summary
# 32617    The film "Al murahikat a.k.a Teenagers" talks ...
# Name: Summary, dtype: object
# New summary
# 1125    The film is a sequel to Ninnishtam Ennishtam a...
# Name: Summary, dtype: object
# New summary
# 11790    Shortly after the events of Hostel, Paxton  is...
# Name: Summary, dtype: object
# New summary
# 8381    The story revolves around a teenage boy named ...
# Name: Summary, dtype: object
# New summary
# 27940    Will Stockdale is a backward, backwoods rube f...
# Name: Summary, dtype: object
# New summary
# 32893    In the third Stooge adaptation of Pygmalion, t...
# Name: Summary, dtype: object
# New summary
# 1413    The story itself is simple: the story of a bea...
# Name: Summary, dtype: object
# New summary
# 2265    Brilliant surgeon Daniel Jekyll  dedicates him...
# Name: Summary, dtype: object
# New summary
# 24679    A series of adventures happen to "Charlie" as ...
# Name: Summary, dtype: object
# New summary
# 57    In 1917, former newspaperman William Gordon  e...
# Name: Summary, dtype: object
# New summary
# 32261    This story was based on a unique point of remo...
# Name: Summary, dtype: object
# New summary
# 34867    When Tora-san returns to visit his family, he ...
# Name: Summary, dtype: object
# New summary
# 17906    The movie is set in a remote village in Dharma...
# Name: Summary, dtype: object
# New summary
# 18817    Devil's Nightmare tells the story of a group o...
# Name: Summary, dtype: object
# New summary
# 1359    A sensuous woman trapped in a loveless relatio...
# Name: Summary, dtype: object
# New summary
# 23593    Will Hay plays the incompetent Fire Captain Vi...
# Name: Summary, dtype: object
# New summary
# 23487    Set in the English village Penny Green in 1939...
# Name: Summary, dtype: object
# New summary
# 21598    Del Diestro plays Isidoro a bored bank teller,...
# Name: Summary, dtype: object
# New summary
# 29022    Jimmy Tong  is an expert blackmailer and thief...
# Name: Summary, dtype: object
# New summary
# 18203    A lady  left from the area when they were kick...
# Name: Summary, dtype: object
# New summary
# 24059    A story centered around a contract worker who ...
# Name: Summary, dtype: object
# New summary
# 16229    The story goes that the Pink Panther visits a ...
# Name: Summary, dtype: object
# New summary
# 32045    The main character, Golan, is a 20 something y...
# Name: Summary, dtype: object
# New summary
# 31996    The story, based on an idea from Salman Khan, ...
# Name: Summary, dtype: object
# New summary
# 22179    Johnny Rizzo  is about to trade his dream job ...
# Name: Summary, dtype: object
# New summary
# 18506    Hitman Joe goes to Bangkok for a month-long as...
# Name: Summary, dtype: object
# New summary
# 35876    This story follows a young student, who is orp...
# Name: Summary, dtype: object
# New summary
# 32242    Jess Wade, a former member of a gang of outlaw...
# Name: Summary, dtype: object
# New summary
# 40109    {{Expand section}} Faten Hamama plays Fatimah,...
# Name: Summary, dtype: object
# New summary
# 40440    Kesavan is a famous singer while his younger b...
# Name: Summary, dtype: object
# New summary
# 23850    {{Plot}} It is New York City, 1905. Miss Lily ...
# Name: Summary, dtype: object
# New summary
# 36528    A retired, scotch-swilling attorney  resides i...
# Name: Summary, dtype: object
# New summary
# 39392    In a nightclub, Teddy Wilson and his orchestra...
# Name: Summary, dtype: object
# New summary
# 22793    When a low-level gangster  is caught having an...
# Name: Summary, dtype: object
# New summary
# 30203    A couple elope by car. The woman's wealthy fat...
# Name: Summary, dtype: object
# New summary
# 2899    A young man returns home from the army, to sta...
# Name: Summary, dtype: object
# New summary
# 42127    Frank Jones  is a retired British naval office...
# Name: Summary, dtype: object
# New summary
# 24690    In the future, Federal Marshal William O'Niel ...
# Name: Summary, dtype: object
# New summary
# 21209    Bittoo Sharma  is street-smart and fun-loving....
# Name: Summary, dtype: object
# New summary
# 17759    It covers the life of Charles II - beginning j...
# Name: Summary, dtype: object
# New summary
# 14210    Cinderella is the much-loved only child of a w...
# Name: Summary, dtype: object
# New summary
# 18711    At seventeen, Veronica "Ronnie" Miller  remain...
# Name: Summary, dtype: object
# New summary
# 41133    Vincent is the story of a young boy, Vincent M...
# Name: Summary, dtype: object
# New summary
# 26619    Fatty plays a somewhat lazy young man who disr...
# Name: Summary, dtype: object
# New summary
# 11777    A tall, thin inventor with a wisp of white smo...
# Name: Summary, dtype: object
# New summary
# 2718    The story focuses on 99 con-men, Karan , Sam  ...
# Name: Summary, dtype: object
# New summary
# 40864    A comedy of manners, the film centers on virtu...
# Name: Summary, dtype: object
# New summary
# 37213    Futile Attraction is about the filming of a re...
# Name: Summary, dtype: object
# New summary
# 25569    Alan and Wendy Barnet are stuck in a marital r...
# Name: Summary, dtype: object
# New summary
# 30086    A mother tells her daughter a real life fairy ...
# Name: Summary, dtype: object
# New summary
# 22475    Set in Delhi in 1962, Lala Jagannath  and Seth...
# Name: Summary, dtype: object
# New summary
# 38111    Seven irrevocably damaged social misfits come ...
# Name: Summary, dtype: object
# New summary
# 18260    Tony Petersen is an electrical tradesman and f...
# Name: Summary, dtype: object
# New summary
# 613    In Edwardian London, Henry Higgins , an arroga...
# Name: Summary, dtype: object
# New summary
# 17879    {{Plot}} On Thanksgiving Day, 1983, student Ma...
# Name: Summary, dtype: object
# New summary
# 31661    Pelíšky is a bittersweet coming-of-age story s...
# Name: Summary, dtype: object
# New summary
# 32168    Sylvester the cat awakes on Christmas morning ...
# Name: Summary, dtype: object
# New summary
# 28535    The film tells the story of an alien whose spa...
# Name: Summary, dtype: object
# New summary
# 39999    Charkavarthy , has two sons Giri and Ranjith ....
# Name: Summary, dtype: object
# New summary
# 7779    Caye  goes to Gloria’s Hair Salon which she fr...
# Name: Summary, dtype: object
# New summary
# 10535    Sasori is outside the prison and on the run fr...
# Name: Summary, dtype: object
# New summary
# 37817    The film chronicles Twyman's and Stokes's rela...
# Name: Summary, dtype: object
# New summary
# 9928    The movie follows a man ([[Paul Jones  who is ...
# Name: Summary, dtype: object
# New summary
# 25297    Crime boss Little John Sarto  retires suddenly...
# Name: Summary, dtype: object
# New summary
# 41348    Day of Wrath is set in a Danish village in 162...
# Name: Summary, dtype: object
# New summary
# 1644    Joe Snow, a snowman, recounts how the Muppet T...
# Name: Summary, dtype: object
# New summary
# 10301    Dexter and Juliet Munro are a married couple w...
# Name: Summary, dtype: object
# New summary
# 19220    High school senior Walter Gibson  and his best...
# Name: Summary, dtype: object
# New summary
# 20115    Roberto Tobias  is a drummer in a rock band wh...
# Name: Summary, dtype: object
# New summary
# 6130    The main characters of the series are the psyc...
# Name: Summary, dtype: object
# New summary
# 7546    Based on the 1978 play by Wallace Shawn, the s...
# Name: Summary, dtype: object
# New summary
# 20134    On her honeymoon, Yūki discovers that her new ...
# Name: Summary, dtype: object
# New summary
# 15867    Fed up with being continuously bullied by his ...
# Name: Summary, dtype: object
# New summary
# 5927    In 2008, terrorists developed a biological wea...
# Name: Summary, dtype: object
# New summary
# 34216    In 1932 Texas, Wilma McClatchie  takes over he...
# Name: Summary, dtype: object
# New summary
# 29120    After a successful business deal in Sacramento...
# Name: Summary, dtype: object
# New summary
# 2754    Married in Canada follows seven American coupl...
# Name: Summary, dtype: object
# New summary
# 17889    Three men and a horse stand in a field. The fi...
# Name: Summary, dtype: object
# New summary
# 15683    In an isolated farmhouse, a woman named Doroth...
# Name: Summary, dtype: object
# New summary
# 28290    Donald is the ranger of a park, in charge of t...
# Name: Summary, dtype: object
# New summary
# 15293    Bill Lawson , a wharf labourer, loses his job ...
# Name: Summary, dtype: object
# New summary
# 28904    Three thirtysomething best friends—a heartbrok...
# Name: Summary, dtype: object
# New summary
# 12762    Judge Somnath lives with his wife, three sons,...
# Name: Summary, dtype: object
# New summary
# 23643    After Eder shows up and confesses to what he h...
# Name: Summary, dtype: object
# New summary
# 38041    Mammootty plays journalist Ravishankar who is ...
# Name: Summary, dtype: object
# New summary
# 1475    The film centers around a rapist and murderer ...
# Name: Summary, dtype: object
# New summary
# 3650    Jean Leonnec  and Marise La Noue  are pennyles...
# Name: Summary, dtype: object
# New summary
# 27654    The film follows the story of an impoverished ...
# Name: Summary, dtype: object
# New summary
# 38267    An ex-boxer Baldev Choudhary  has had a stain ...
# Name: Summary, dtype: object
# New summary
# 33712    The film begins with the coronation of Karl Al...
# Name: Summary, dtype: object
# New summary
# 42167    The film opens with a shot of a barefooted wom...
# Name: Summary, dtype: object
# New summary
# 39449    In the late 90's, Durval  is a middle aged man...
# Name: Summary, dtype: object
# New summary
# 17122    When Porky finds a golden egg in his henhouse,...
# Name: Summary, dtype: object
# New summary
# 17898    Following the death of her husband, Ruth Matth...
# Name: Summary, dtype: object
# New summary
# 40298    Trip is the diary of a Sudanese girl moving to...
# Name: Summary, dtype: object
# New summary
# 32818    In this cartoon, Professor Owl teaches his cla...
# Name: Summary, dtype: object
# New summary
# 5307    This film is about the a man who travels from ...
# Name: Summary, dtype: object
# New summary
# 36418    Jim Hardy , Ted Hanover , and Lila Dixon  have...
# Name: Summary, dtype: object
# New summary
# 655    Following the events of Puppet Master 4, Rick ...
# Name: Summary, dtype: object
# New summary
# 15746    The story revolves around 11-year-old Jessica ...
# Name: Summary, dtype: object
# New summary
# 20095    Two Kurdish refugees from Iraq, a father and s...
# Name: Summary, dtype: object
# New summary
# 29506    The story opens with a group of people travell...
# Name: Summary, dtype: object
# New summary
# 34401    The movie tells the story of Elizabeth  and Jo...
# Name: Summary, dtype: object
# New summary
# 39461    David  and Catherine Robinson  move into a run...
# Name: Summary, dtype: object
# New summary
# 41449    Vallarasu  is the deputy commissioner of polic...
# Name: Summary, dtype: object
# New summary
# 9630    By 2044, the United States has suffered econom...
# Name: Summary, dtype: object
# New summary
# 30922     Porky is looking all over the big city for a ...
# Name: Summary, dtype: object
# New summary
# 18771    The film tells the story of a jailed woman who...
# Name: Summary, dtype: object
# New summary
# 38302    Soorma Bhopali is the owner of a Timber mart. ...
# Name: Summary, dtype: object
# New summary
# 14516    During the current term at Maudlin Street Seco...
# Name: Summary, dtype: object
# New summary
# 591    A crazed scientist, Morder , driven even crazi...
# Name: Summary, dtype: object
# New summary
# 42258    Jill Trevor  vows revenge on newspaper baron S...
# Name: Summary, dtype: object
# New summary
# 32193    Pierre Deneige , well known as a scoundrel, is...
# Name: Summary, dtype: object
# New summary
# 9452    While serving in the Middle East, Sergeant Bra...
# Name: Summary, dtype: object
# New summary
# 4585    The primary characters are earnest aspiring no...
# Name: Summary, dtype: object
# New summary
# 2779    The film opens with a trio of explorers in Afr...
# Name: Summary, dtype: object
# New summary
# 19039    John Tucker, a bounty hunter comes face to fac...
# Name: Summary, dtype: object
# New summary
# 33592    Pfc. Franklin Bean  gets drunk and goes AWOL u...
# Name: Summary, dtype: object
# New summary
# 9177    Stroker Ace is a popular race car driver from ...
# Name: Summary, dtype: object
# New summary
# 27286    George , recently released from prison, is giv...
# Name: Summary, dtype: object
# New summary
# 12727    Sethumadhavan  is released after serving an im...
# Name: Summary, dtype: object
# New summary
# 34824    Sumalatha plays the role of Isabella, a tour g...
# Name: Summary, dtype: object
# New summary
# ...
# New summary
# 5757    Set in the 1950s, the film begins with a confr...
# Name: Summary, dtype: object
# New summary
# 40361    Speedy Gonzales invades Granny's home and driv...
# Name: Summary, dtype: object
# New summary
# 10958    One day, in his rush to grab hold of a falling...
# Name: Summary, dtype: object
# New summary
# 28338    Prabhu , despite having all the required quali...
# Name: Summary, dtype: object
# New summary
# 1894    Cops take sexual advantage of the men they pul...
# Name: Summary, dtype: object
# New summary
# 16153    The gang play baseball until they are run off ...
# Name: Summary, dtype: object
# New summary
# 36711    The film centers on Themistocles and Artemisia...
# Name: Summary, dtype: object
# New summary
# 27797    Zerelda King is assigned to look into possible...
# Name: Summary, dtype: object
# New summary
# 12315    An adventuress, Cora Williams  destroys the ha...
# Name: Summary, dtype: object
# New summary
# 6220    The film begins in Ban Nong Pradu, a rural vil...
# Name: Summary, dtype: object
# New summary
# 3675    A young black woman arrives at the home of a b...
# Name: Summary, dtype: object
# New summary
# 21229    Mr and Mrs Smedhurst  are a middle-aged busine...
# Name: Summary, dtype: object
# New summary
# 36173    James Cole  is a convicted criminal living in ...
# Name: Summary, dtype: object
# New summary
# 27010    Seetha Kalyanam is the story of Seetha's  sway...
# Name: Summary, dtype: object
# New summary
# 11463    Sambaiah  is a cobbler who raises his dead sis...
# Name: Summary, dtype: object
# New summary
# 8206    Love story of Premadasa and Mallika. Cast * as...
# Name: Summary, dtype: object
# New summary
# 28629    O' Faby tells the story of the friendship betw...
# Name: Summary, dtype: object
# New summary
# 38556    Joey Lawrence  plays hit man, Lyle Wilkes, in ...
# Name: Summary, dtype: object
# New summary
# 38735    Joe Bell  becomes embittered after he is jaile...
# Name: Summary, dtype: object
# New summary
# 29196    The film revolves around three young anti-capi...
# Name: Summary, dtype: object
# New summary
# 6044    The documentary painted a hopeless and pessimi...
# Name: Summary, dtype: object
# New summary
# 31238    Eloise , the daughter of the renowned swordsma...
# Name: Summary, dtype: object
# New summary
# 19746    An American couple  finds a family of survivin...
# Name: Summary, dtype: object
# New summary
# 33054    Todd Howard , the cousin of Scott Howard, has ...
# Name: Summary, dtype: object
# New summary
# 10371    A Canadian officer is sent on a secret and dan...
# Name: Summary, dtype: object
# New summary
# 37146    Lola  is a pretty teenage girl living with her...
# Name: Summary, dtype: object
# New summary
# 33013    The action takes place at the beginning of 20t...
# Name: Summary, dtype: object
# New summary
# 17252    When 12-year-old Pamela goes on vacation with ...
# Name: Summary, dtype: object
# New summary
# 41619    Main character John McKenna  is a spiritual be...
# Name: Summary, dtype: object
# New summary
# 2945    The Invitation tells the story of a group of o...
# Name: Summary, dtype: object
# New summary
# 34366    Monroe Stahr  is the young production chief an...
# Name: Summary, dtype: object
# New summary
# 31162    The film is set in the mountainous regions of ...
# Name: Summary, dtype: object
# New summary
# 2058    Journalist Simon Morris has trouble with his l...
# Name: Summary, dtype: object
# New summary
# 36557    A man  wanders through a heavy rainstorm findi...
# Name: Summary, dtype: object
# New summary
# 29172    An old man has three sons: the elder two are c...
# Name: Summary, dtype: object
# New summary
# 40777    Dad Hayseed buys a horse for ₤20 called Cornst...
# Name: Summary, dtype: object
# New summary
# 39773    In an attempt to impress his American girlfrie...
# Name: Summary, dtype: object
# New summary
# 24687    Jong-hwan and Su-kyung meet in a cafe. Jong-hw...
# Name: Summary, dtype: object
# New summary
# 29447    A portrait of the everyday life of a typical m...
# Name: Summary, dtype: object
# New summary
# 8992    During the 12th and 15th centuries, in Muslim ...
# Name: Summary, dtype: object
# New summary
# 33061    "Mike" , age 6, arrives in New York to stay wi...
# Name: Summary, dtype: object
# New summary
# 30510    In 1961, the Soviet Union launches its first b...
# Name: Summary, dtype: object
# New summary
# 39281    Hal Larson  is a superficial man whose fixatio...
# Name: Summary, dtype: object
# New summary
# 4760    In the town of Crescent Cove, California, Farm...
# Name: Summary, dtype: object
# New summary
# 24614    Unnikrishan  wants to become a secret agent li...
# Name: Summary, dtype: object
# New summary
# 29019    A group of reporters are covering the unveilin...
# Name: Summary, dtype: object
# New summary
# 18963    Nine-year-old Evelyn Doyle's  mother has aband...
# Name: Summary, dtype: object
# New summary
# 18239    {{Expand section}} The brochures in a travel a...
# Name: Summary, dtype: object
# New summary
# 36175    John Wayne portrays a college football coach  ...
# Name: Summary, dtype: object
# New summary
# 35342    Paul Racine , a computer-chip executive from N...
# Name: Summary, dtype: object
# New summary
# 948    Opening - The Wiggles wave their hands up high...
# Name: Summary, dtype: object
# New summary
# 31434    Teenager Angus  adopts a Yellow Labrador Retri...
# Name: Summary, dtype: object
# New summary
# 12546    {{Plot}} Smith is an 18-year-old film student ...
# Name: Summary, dtype: object
# New summary
# 26273    Kenny is a mockumentary that follows the ficti...
# Name: Summary, dtype: object
# New summary
# 5466    Little Mute  is a new Shaolin student who is m...
# Name: Summary, dtype: object
# New summary
# 14332    Major Parashuram is an ex-army man, running a ...
# Name: Summary, dtype: object
# New summary
# 24763    The film focuses on an all-girl college where ...
# Name: Summary, dtype: object
# New summary
# 10230    Hyeon-Jeong  got kicked to the curb by Min-Seo...
# Name: Summary, dtype: object
# New summary
# 12963    Bruno , a student at the rundown FW Murnau Fil...
# Name: Summary, dtype: object
# New summary
# 15940    Corporate centers around the power games betwe...
# Name: Summary, dtype: object
# New summary
# 8329    In the near future, Detroit, Michigan is on th...
# Name: Summary, dtype: object
# New summary
# 20156    Soichi Negishi is a shy young musician who dre...
# Name: Summary, dtype: object
# New summary
# 34814    Relations are strained between cattle baron Br...
# Name: Summary, dtype: object
# New summary
# 5540    The children of old-fashioned patriarch of a f...
# Name: Summary, dtype: object
# New summary
# 37400    Melinda Uy is a billionaire widow whose life i...
# Name: Summary, dtype: object
# New summary
# 2851    In 1995 Hollywood, novice screenwriter Robert ...
# Name: Summary, dtype: object
# New summary
# 29289    Saul Naumann  is a somewhat controlling Jewish...
# Name: Summary, dtype: object
# New summary
# 33498    The story is based loosely on real events and ...
# Name: Summary, dtype: object
# New summary
# 18380    The film brings together the video diaries rec...
# Name: Summary, dtype: object
# New summary
# 2108    Yugoslav partisans grimly crop the hair of a v...
# Name: Summary, dtype: object
# New summary
# 11169    A German paratrooper is seen being injured and...
# Name: Summary, dtype: object
# New summary
# 14451    'Ozhimuri' is based on the story of the book '...
# Name: Summary, dtype: object
# New summary
# 36031     In the attic of a large house, Tom is busy de...
# Name: Summary, dtype: object
# New summary
# 9311    The Sky Pilot arrives in a rough and tumble no...
# Name: Summary, dtype: object
# New summary
# 31346    Ex-fighter pilot and taxi driver Ted Striker  ...
# Name: Summary, dtype: object
# New summary
# 27712    Two close friends, Martin Schulz and Max Eisen...
# Name: Summary, dtype: object
# New summary
# 14198    The story opens with Rahul  and his best frien...
# Name: Summary, dtype: object
# New summary
# 39719    Stork is a 6 foot 7 hypochondriac who dreams o...
# Name: Summary, dtype: object
# New summary
# 1139    The story centers around Roy’s Grill, a fixtur...
# Name: Summary, dtype: object
# New summary
# 33236    The movie revolves around Eun Sook , a lovely ...
# Name: Summary, dtype: object
# New summary
# 15641    The movie deals with the Malabar rebellion, mo...
# Name: Summary, dtype: object
# New summary
# 19321    The film tells the story of Giancarlo Siani, a...
# Name: Summary, dtype: object
# New summary
# 35536    Lara Tyler  is one of the most famous movie st...
# Name: Summary, dtype: object
# New summary
# 31974    Catching up with Hansel  and Gretel , fifteen ...
# Name: Summary, dtype: object
# New summary
# 35256    Wild Combination begins with interviews of Rus...
# Name: Summary, dtype: object
# New summary
# 11599    There is something horribly wrong with the bod...
# Name: Summary, dtype: object
# New summary
# 17705    In a bridge across a sea, saxophone music is h...
# Name: Summary, dtype: object
# New summary
# 20529    {{plot}} An old Norwegian woman named Helga  w...
# Name: Summary, dtype: object
# New summary
# 34548    A tilted figure, consisting largely of right a...
# Name: Summary, dtype: object
# New summary
# 22196    The film is a parody of community theater set ...
# Name: Summary, dtype: object
# New summary
# 32552    The British Navy in Port Said is making plans ...
# Name: Summary, dtype: object
# New summary
# 2182    The film begins with an attempted assassinatio...
# Name: Summary, dtype: object
# New summary
# 27166    Sivankutty ([[Dileep  is a big fan of Super st...
# Name: Summary, dtype: object
# New summary
# 18255    Mrs. Callahan  and Mrs. Murphy , are a couple ...
# Name: Summary, dtype: object
# New summary
# 17891    Sabrina is turning 13 years old receiving her ...
# Name: Summary, dtype: object
# New summary
# 12116    The film is set in 1940s Shanghai and Hong Kon...
# Name: Summary, dtype: object
# New summary
# 17762    Pat Delaney is working in a circus as one of t...
# Name: Summary, dtype: object
# New summary
# 36189    A strange man owns a self-storage facility and...
# Name: Summary, dtype: object
# New summary
# 22073    Makoto , a high school science and chemistry t...
# Name: Summary, dtype: object
# New summary
# 20146    After 17-year-old misfit Jones Dillon drops ou...
# Name: Summary, dtype: object
# New summary
# 35402    Junior Healy  tells a story from multiple draw...
# Name: Summary, dtype: object
# New summary
# 34387    The movie is based on Kerala's traditional Vad...
# Name: Summary, dtype: object
# New summary
# 25072    {{plot}} The movie begins with Buford  remembe...
# Name: Summary, dtype: object
# New summary
# 30671     Debu  is a 32 year old advertising agent, but...
# Name: Summary, dtype: object
# New summary
# 9573    Patsy Cline  is unhappily married and playing ...
# Name: Summary, dtype: object
# New summary
# 21963    Small town youth Jimmie Bates  is a well-inten...
# Name: Summary, dtype: object
# New summary
# 11720    Woodrow "Woody" Wilkins  is an imaginative, ye...
# Name: Summary, dtype: object
# New summary
# 5742    The film begins in a modern home with two chil...
# Name: Summary, dtype: object
# New summary
# 32285    Grace Milroy loses her job working at a factor...
# Name: Summary, dtype: object
# New summary
# 12257    The story is set around 1580, in the time of K...
# Name: Summary, dtype: object
# New summary
# 21943    The story follows a group of partygoers who ar...
# Name: Summary, dtype: object
# New summary
# 19539    The film starts by telling the story of Tony's...
# Name: Summary, dtype: object
# New summary
# 41727    Freelancer Liu Yuan  is a carefree Beijing nat...
# Name: Summary, dtype: object
# New summary
# 29313    The story opens at a fabric dyeing mill. The q...
# Name: Summary, dtype: object
# New summary
# 9248    The plot revolves around a group of fun-loving...
# Name: Summary, dtype: object
# New summary
# 41666    The movie focuses on Daphne , the loving but o...
# Name: Summary, dtype: object
# New summary
# 1982    Senthil Kumar ([[Prasanna  and Malini ([[Sneha...
# Name: Summary, dtype: object
# New summary
# 36023    The film is set in the year 1938, when India w...
# Name: Summary, dtype: object
# New summary
# 34343    Srinivasan  is a owner of Ad Agency which is g...
# Name: Summary, dtype: object
# New summary
# 17439    A inmate named Salem  escapes from an insane a...
# Name: Summary, dtype: object
# New summary
# 35490    In 1994, between April and July, the massacre ...
# Name: Summary, dtype: object
# New summary
# 1845    Norma and Malcolm Miochaels are a middle-aged ...
# Name: Summary, dtype: object
# New summary
# 26450    The film begins with a group of nurses at a ps...
# Name: Summary, dtype: object
# New summary
# 9979    During a Mardi Gras parade in New Orleans, a y...
# Name: Summary, dtype: object
# New summary
# 22407    {{Expand section}} Against the backdrop of the...
# Name: Summary, dtype: object
# New summary
# 25385    Set in the near future, a small gang of revolu...
# Name: Summary, dtype: object
# New summary
# 31564    The story begins as Hollywood press agent Bill...
# Name: Summary, dtype: object
# New summary
# 9034    Red Sonja  is visited by a spirit who grants h...
# Name: Summary, dtype: object
# New summary
# 4997    Writer Muraki becomes obsessed with a porn sta...
# Name: Summary, dtype: object
# New summary
# 84    It is spring. Randy Dean is a high school seni...
# Name: Summary, dtype: object
# New summary
# 3899    {{Expand section}} Parker Ballantine is a thea...
# Name: Summary, dtype: object
# New summary
# 38292    The Stooges help a destitute mother and her da...
# Name: Summary, dtype: object
# New summary
# 18500    The film starts with a young, blonde woman, ve...
# Name: Summary, dtype: object
# New summary
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\margu\OneDrive\Documents\MA3\ada\Project1\movies.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/margu/OneDrive/Documents/MA3/ada/Project1/movies.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> for i in filtered_movies.index:
#       <a href='vscode-notebook-cell:/c%3A/Users/margu/OneDrive/Documents/MA3/ada/Project1/movies.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a>     print("New summary")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/margu/OneDrive/Documents/MA3/ada/Project1/movies.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a>     plot=movie_summaries[movie_summaries['Wiki ID']==filtered_movies.loc[i]['Wiki ID']]['Summary']
#       <a href='vscode-notebook-cell:/c%3A/Users/margu/OneDrive/Documents/MA3/ada/Project1/movies.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a>     #plot=str(movie_summaries.loc[i]['Summary'])
#       <a href='vscode-notebook-cell:/c%3A/Users/margu/OneDrive/Documents/MA3/ada/Project1/movies.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a>     print(plot)
#
# File c:\Users\margu\anaconda3\envs\ada\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\margu\anaconda3\envs\ada\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\margu\anaconda3\envs\ada\lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\margu\anaconda3\envs\ada\lib\site-packages\pandas\core\ops\array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\margu\anaconda3\envs\ada\lib\site-packages\pandas\core\ops\array_ops.py:83, in comp_method_OBJECT_ARRAY(op, x, y)
#      81 else:
#      82     result = libops.scalar_compare(x.ravel(), y, op)
# ---> 83 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Version 2

# %%
name=''
for i in range(0,1):
    print("New film")
    plot=str(movie_summaries[movie_summaries['Wiki ID']==movies.loc[i]['Wiki ID']]['Summary'])
    char_names=str(char[char['Wiki ID']==movies.loc[i]['Wiki ID']]['char name'])
    n_words=len(plot.split())
    names=[]
    name_groups = {}
    
    if n_words>=2:
        print("Summary of film {0}:".format(i), plot)
        nltk_results = ne_chunk(pos_tag(word_tokenize(plot)))
        for nltk_result in nltk_results:
            if type(nltk_result) == Tree:
                name = ''
                for nltk_result_leaf in nltk_result.leaves():
                    name += nltk_result_leaf[0] + ' '
                names.append(name)

 
    for name in names:
        match_found = False
        name_parts = name.strip().lower().split()
        if len(name_parts) == 2:
            #If full name
            first_name, last_name = name_parts
        elif len(name_parts) == 1:
            #If single name
            first_name, last_name= name_parts[0],""
        else:
            break

        full_name = (first_name, last_name)


        # If name mentionned multiple times, group the mentions
        for group, members in name_groups.items():
            if len(name_parts) == 1:
                if first_name in group[0] or first_name in group[1]:
                    members.append(name)
                    match_found = True
            elif first_name in group[0] or last_name in group[1] or first_name in group[1] or last_name in group[0]:
                members.append(name)
                match_found = True
                break

        if not match_found:
            name_groups[full_name] = [name]

    
    # Match names detected to character of char dataset
    for name in char_names:
        mention=False
        print(name)
        # char_name_parts = name.strip().lower().split()
        # for group, members in name_groups.items():
        #     for word in char_name_parts:
        #         if word in group:
        #             print("Name", name, "has", len(members), "mentions")
        #             mention=True
        #             # for now assign the number of mentions to each character
        #             char.loc[char['char name'] == name, 'role'] = len(members)
        #             break
        # if mention==False:
        #     char.loc[char['char name'] == name, 'role'] = 0
        #     print("Name", name, "has", 0, "mentions")
# Out:
# New film
# Summary of film 0: 22382    Set in the second half of the 22nd century, the film depicts Mars as a planet that has been 84% terraformed, allowing humans to walk on the surface without wearing pressure suits. The Martian society has become largely matriarchal, with women in most positions of authority. The story concerns a police officer, Melanie Ballard , second in command of a small team alongside Sergeant Jericho  sent to pick up and transport a prisoner named Desolation Williams . Arriving at the remote mining town where Williams is being held, Ballard finds virtually all of the people missing. She learns that the miners had discovered an underground doorway created by an ancient Martian civilization. When the door was opened it released "ghosts," disembodied spirits which possessed the miners. Violence ensues, as the possessed miners commit horrific acts of death and destruction, as well as self-mutilation. With their team leader Helena Bradock  murdered, Ballard must fight off the attacking miners, escape the town, and destroy the ghosts, if possible. Unfortunately, her intentions are complicated by the fact that killing a possessed human merely releases the Martian spirit to possess another human. The team eventually decides to blow up a nuclear reactor to try and vaporize all of the ghosts. At several points in the film Sergeant Jericho shows a romantic interest in Ballard, mostly unreciprocated. Ballard's crew along with survivors who manage to gather in the jail are eventually wiped out by the miners after many fierce battles and events , leaving only her and Williams after Sergeant Jericho and the other remaining officers and the two operators of the train are killed upon returning from a brief retreat to finish the fight. Not wanting the authorities to blame the massacre on him, he handcuffs Ballard to her cot and escapes from the train, leaving her to return home and deliver her report, which is received with skepticism by her superiors. While Ballard recuperates at a hospital, the released spirits, who weren't destroyed after all, attack the city. The end scene sets the movie up for a sequel as Williams returns to team up with Ballard to fight the possessed.
# Name: Summary, dtype: object
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A
# k
# o
# o
# s
# h
# a
# y
#
#
# 1
#
#
#
#
#
# L
# i
# e
# u
# t
# e
# n
# a
# n
# t
#
# M
# e
# l
# a
# n
# i
# e
#
# B
# a
# l
# l
# a
# r
# d
#
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
# D
# e
# s
# o
# l
# a
# t
# i
# o
# n
#
# W
# i
# l
# l
# i
# a
# m
# s
#
#
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
# S
# g
# t
#
# J
# e
# r
# i
# c
# h
# o
#
# B
# u
# t
# l
# e
# r
#
#
# 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# B
# a
# s
# h
# i
# r
# a
#
# K
# i
# n
# c
# a
# i
# d
#
#
# 5
#
#
#
#
#
#
# C
# o
# m
# m
# a
# n
# d
# e
# r
#
# H
# e
# l
# e
# n
# a
#
# B
# r
# a
# d
# d
# o
# c
# k
#
#
# 6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# W
# h
# i
# t
# l
# o
# c
# k
#
#
# 7
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# B
# i
# g
#
# D
# a
# d
# d
# y
#
# M
# a
# r
# s
#
#
# 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# M
# i
# c
# h
# a
# e
# l
#
# D
# e
# s
# c
# a
# n
# s
# o
#
#
# 9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# U
# n
# o
#
#
# 1
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# D
# o
# s
#
#
# 1
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# T
# r
# e
# s
#
#
# 1
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# M
# c
# S
# i
# m
# m
# s
#
#
# 1
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Z
# i
# m
# m
# e
# r
# m
# a
# n
#
#
# 1
# 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# B
# e
# n
# c
# h
# l
# e
# y
#
#
# 1
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# R
# o
# d
# a
# l
# e
#
#
# N
# a
# m
# e
# :
#
# c
# h
# a
# r
#
# n
# a
# m
# e
# ,
#
# d
# t
# y
# p
# e
# :
#
# o
# b
# j
# e
# c
# t
#    Wiki ID   movie ID release date                   char name         DOB  \
# 0   975900  /m/03vyhn   2001-08-24                    Akooshay  1958-08-26
# 1   975900  /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
# 2   975900  /m/03vyhn   2001-08-24         Desolation Williams  1969-06-15
# 3   975900  /m/03vyhn   2001-08-24          Sgt Jericho Butler  1967-09-12
# 4   975900  /m/03vyhn   2001-08-24             Bashira Kincaid  1977-09-25
#
#   gender  heght   ethnicity          actor name  actor age      map ID  \
# 0      F  1.620         NaN      Wanda De Jesus       42.0  /m/0bgchxw
# 1      F  1.780  /m/044038p  Natasha Henstridge       27.0   /m/0jys3m
# 2      M  1.727     /m/0x67            Ice Cube       32.0   /m/0jys3g
# 3      M  1.750         NaN       Jason Statham       33.0  /m/02vchl6
# 4      F  1.650         NaN         Clea DuVall       23.0  /m/02vbb3r
#
#       char ID    actor ID  role
# 0  /m/0bgcj3x  /m/03wcfv7   0.0
# 1  /m/0bgchn4   /m/0346l4   0.0
# 2  /m/0bgchn_  /m/01vw26l   0.0
# 3  /m/0bgchnq   /m/034hyc   0.0
# 4  /m/0bgchp9   /m/01y9xg   0.0

# %%
char.head()
# Out:
#    Wiki ID   movie ID release date                   char name         DOB  \
# 0   975900  /m/03vyhn   2001-08-24                    Akooshay  1958-08-26
# 1   975900  /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
# 2   975900  /m/03vyhn   2001-08-24         Desolation Williams  1969-06-15
# 3   975900  /m/03vyhn   2001-08-24          Sgt Jericho Butler  1967-09-12
# 4   975900  /m/03vyhn   2001-08-24             Bashira Kincaid  1977-09-25
#
#   gender  heght   ethnicity          actor name  actor age      map ID  \
# 0      F  1.620         NaN      Wanda De Jesus       42.0  /m/0bgchxw
# 1      F  1.780  /m/044038p  Natasha Henstridge       27.0   /m/0jys3m
# 2      M  1.727     /m/0x67            Ice Cube       32.0   /m/0jys3g
# 3      M  1.750         NaN       Jason Statham       33.0  /m/02vchl6
# 4      F  1.650         NaN         Clea DuVall       23.0  /m/02vbb3r
#
#       char ID    actor ID  role
# 0  /m/0bgcj3x  /m/03wcfv7   0.0
# 1  /m/0bgchn4   /m/0346l4   0.0
# 2  /m/0bgchn_  /m/01vw26l   0.0
# 3  /m/0bgchnq   /m/034hyc   0.0
# 4  /m/0bgchp9   /m/01y9xg   0.0

# %%
name=''
#for i in range(1,2):
for i in filtered_movies.index:
    print("New film")
    #plot=str(movie_summaries[movie_summaries['Wiki ID']==str(movies.loc[i]['Wiki ID'])]['Summary'])
    plot=str(movie_summaries[movie_summaries['Wiki ID']==filtered_movies.loc[i]['Wiki ID']]['Summary'])
    char_names=str(char[char['Wiki ID']==filtered_movies.loc[i]['Wiki ID']]['char name'])
    n_words=len(plot.split())
    names=[]
    name_groups = {}
    if n_words>=2:
        print("Summary of film {0}:".format(i), plot)
        nltk_results = ne_chunk(pos_tag(word_tokenize(plot)))
        for nltk_result in nltk_results:
            if type(nltk_result) == Tree:
                name = ''
                for nltk_result_leaf in nltk_result.leaves():
                    name += nltk_result_leaf[0] + ' '
                names.append(name)

 
    for name in names:
        match_found = False
        name_parts = name.strip().lower().split()
        if len(name_parts) == 2:
            #If full name
            first_name, last_name = name_parts
        elif len(name_parts) == 1:
            #If single name
            first_name, last_name= name_parts[0],""
        else:
            break

        full_name = (first_name, last_name)


        # If name mentionned multiple times, group the mentions
        for group, members in name_groups.items():
            if len(name_parts) == 1:
                if first_name in group[0] or first_name in group[1]:
                    members.append(name)
                    match_found = True
            elif first_name in group[0] or last_name in group[1] or first_name in group[1] or last_name in group[0]:
                members.append(name)
                match_found = True
                break

        if not match_found:
            name_groups[full_name] = [name]

    
    # Match names detected to character of char dataset
    for name in char_names:
        mention=False
        char_name_parts = name.strip().lower().split()
        for group, members in name_groups.items():
            for word in char_name_parts:
                if word in group:
                    print("Name", name, "has", len(members), "mentions")
                    mention=True
                    # for now assign the number of mentions to each character
                    char.loc[char['char name'] == name, 'role'] = len(members)
                    break
        if mention==False:
            char.loc[char['char name'] == name, 'role'] = 0
            print("Name", name, "has", 0, "mentions")

# %% [markdown]
# ### Assign a categorical value based on the number of mentions compared to other characters of the same movie
# #### 0: small role (not mentionned in summary)
# #### 1: secondary role (mentionned in summary)
# #### 2: lead role (mentionned considerabely more than others)

# %%
mentions=char[char['Wiki ID']==movies.loc[0]['Wiki ID']]['role']

# %%
char.head()
# Out:
#    Wiki ID   movie ID release date                   char name         DOB  \
# 0   975900  /m/03vyhn   2001-08-24                    Akooshay  1958-08-26
# 1   975900  /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard  1974-08-15
# 2   975900  /m/03vyhn   2001-08-24         Desolation Williams  1969-06-15
# 3   975900  /m/03vyhn   2001-08-24          Sgt Jericho Butler  1967-09-12
# 4   975900  /m/03vyhn   2001-08-24             Bashira Kincaid  1977-09-25
#
#   gender  heght   ethnicity          actor name  actor age      map ID  \
# 0      F  1.620         NaN      Wanda De Jesus       42.0  /m/0bgchxw
# 1      F  1.780  /m/044038p  Natasha Henstridge       27.0   /m/0jys3m
# 2      M  1.727     /m/0x67            Ice Cube       32.0   /m/0jys3g
# 3      M  1.750         NaN       Jason Statham       33.0  /m/02vchl6
# 4      F  1.650         NaN         Clea DuVall       23.0  /m/02vbb3r
#
#       char ID    actor ID  role
# 0  /m/0bgcj3x  /m/03wcfv7     0
# 1  /m/0bgchn4   /m/0346l4     8
# 2  /m/0bgchn_  /m/01vw26l     4
# 3  /m/0bgchnq   /m/034hyc     3
# 4  /m/0bgchp9   /m/01y9xg     0

# %% [markdown]
# # Actors Career

# %%
actor_data_folder = './Data/Actors/'
names = pd.read_csv(actor_data_folder+'name.tsv', sep='\t')

# %%
principals = pd.read_csv(actor_data_folder+'principals.tsv', sep='\t')
